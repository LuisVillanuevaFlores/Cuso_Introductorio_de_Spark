# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisVillanuevaFlores/Cuso_Introductorio_de_Spark/blob/master/Platzi_Spark_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime
print(datetime.datetime.now())

#INSTALACION

# instalar JAVA
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# instalar Spark
# !wget -q https://downloads.apache.org/spark/spark-3.0.3/spark-3.0.3-bin-hadoop3.2.tgz
# !tar xf spark-3.0.3-bin-hadoop3.2.tgz

# instalar para usar con pypthon
# !pip install -q findspark
# Out:
# 2021-07-09 17:44:56.839253

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-2.4.8-bin-hadoop2.7"

# %%
import findspark
findspark.init()
from pyspark import SparkContext 
from pyspark.sql import SparkSession

# %%
#SUBIDA DE ARCHIVOS
from google.colab import files
#files.upload()

# %%
path ="/content/"
# sc = SparkContext(master = "local" , appName="bigrama")
datos = sc.textFile(path+"pg10.txt") \
  .map(lambda l : l.split(" ")) \
  .flatMap(lambda l: [((l[i],l[i+1]),1) for i in range (0, len(l)-1)]) \
  .reduceByKey(lambda a,b: a+b) 

datos.collect()
# datos.saveAsTextFile(path+"res.txt")
# Out:
# [(('The', 'Project'), 3),
#  (('Project', 'Gutenberg'), 19),
#  (('Gutenberg', 'EBook'), 2),
#  (('EBook', 'of'), 2),
#  (('of', 'The'), 2),
#  (('The', 'King'), 4),
#  (('King', 'James'), 6),
#  (('James', 'Bible'), 5),
#  (('EBOOK', '(#10)'), 1),
#  (('(#10)', 'WAS'), 1),
#  (('WAS', 'ONE'), 1),
#  (('ONE', 'OF'), 1),
#  (('OF', 'PROJECT'), 1),
#  (('PROJECT', "GUTENBERG'S"), 1),
#  (("GUTENBERG'S", 'EARLY'), 1),
#  (('EARLY', 'FILES'), 1),
#  (('FILES', 'PRODUCED'), 1),
#  (('PRODUCED', 'AT'), 1),
#  (('AT', 'A'), 1),
#  (('TIME', 'WHEN'), 1),
#  (('WHEN', 'PROOFING'), 1),
#  (('PROOFING', 'METHODS'), 1),
#  (('METHODS', 'AND'), 1),
#  (('AND', 'TOOLS'), 1),
#  (('TOOLS', 'WERE'), 1),
#  (('WERE', 'NOT'), 1),
#  (('NOT', 'WELL'), 1),
#  (('WELL', 'DEVELOPED.'), 1),
#  (('DEVELOPED.', 'THERE'), 1),
#  (('THERE', 'IS'), 1),
#  (('AN', 'IMPROVED'), 1),
#  (('IMPROVED', 'EDITION'), 1),
#  (('EDITION', 'OF'), 1),
#  (('OF', 'THIS'), 3),
#  (('THIS', 'TITLE'), 1),
# ...
